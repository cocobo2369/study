# %% [markdown]
# # 실기 대비
# # 실전 문제풀이
# # set 1
#
# ## 1) 데이터 및 시나리오
#
# ### 시중 TV 제품별 분석
#
# > 시중 판매 중인 TV정보를 온라인 쇼핑몰 웹페이지에서 크롤링 하여 분석을 하고자 한다. 해당 데이터를 기반으로 각 TV의 제원은 어떤 한지 제원에 따른 평가는 어떤 한지 알아보고 향후 신제품 출시에 참고하고자 한다.
#
# ### 데이터 개요
#
# | 파일명 | 행 | 열 | 인코딩 |
# |---|---:|---:|---|
# | `TV.csv` | 666 | 11 | UTF-8 |
#
# ### 변수 상세
#
# | 변수명 | 유형 | 설명 |
# |---|---|---|
# | `Product_Name` | string | 상품명 |
# | `Stars` | float | 평가 평균 점수 |
# | `Ratings` | int | 평가 수 |
# | `Reviews` | int | 후기 수 |
# | `current_price` | int | 현재 가격 |
# | `MRP` | int | 공장 출고가 |
# | `channel` | string | 프리미엄 채널 서비스 제공 목록 |
# | `Operating_system` | string | 운영체제 |
# | `Picture_quality` | string | 해상도 |
# | `Speaker` | string | 스피커 |
# | `Frequency` | string | 주사율 |
#
# ## 2) 문제
#
# ### 필요 라이브러리 함수 및 클래스 목록
#
# | 목록 |
# |---|
# | `from sklearn.ensemble import RandomForestRegressor` |

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('../dataset/TV.csv')

#SCDI
display(df.shape)
display(df.columns)
display(df.dtypes)
display(df.isna().sum())
# Out:
# (666, 11)
# Index(['Product_Name', 'Stars', 'Ratings', 'Reviews', 'current_price', 'MRP',
#        'channel', 'Operating_system', 'Picture_quality', 'Speaker',
#        'Frequency'],
#       dtype='object')
# Product_Name         object
# Stars               float64
# Ratings               int64
# Reviews               int64
# current_price         int64
# MRP                   int64
# channel              object
# Operating_system     object
# Picture_quality      object
# Speaker              object
# Frequency            object
# dtype: object
# Product_Name        0
# Stars               0
# Ratings             0
# Reviews             0
# current_price       0
# MRP                 0
# channel             0
# Operating_system    0
# Picture_quality     0
# Speaker             0
# Frequency           0
# dtype: int64

# %% [markdown]
# ### Q01.
#
# 주사율(`Frequency`)은 TV 제원 중 가격에 큰 영향을 미치는 제원이다.
# 그런데 데이터 수집 중 실수가 발생하여 주사율(`Frequency`) 값 중 일부가 해상도(`Picture_quality`), 스피커(`Speaker`) 변수에 잘못 입력된 것이 발견되었다.
# 세 변수에 들어간 주사율 데이터를 취합하여 전체 TV 중에서 주사율이 60Hz인 TV는 총 몇 대 인가?
#
# ※ 주사율은 2~3자리 숫자 뒤에 반드시 `Hz`라는 단위로 표기되어 있다.
# ※ 세 변수 모두 주사율 정보가 없는 경우 결측치로 간주하고 이를 분석에서 제외하시오. `(정답 예시: 12)`

# %%
df_q1 = df.copy()
display(df_q1['Frequency'].unique())
display(df_q1['Picture_quality'].unique())
display(df_q1['Speaker'].unique())
ser = df_q1['Frequency'] + df_q1['Picture_quality'] + df_q1['Speaker']
display(ser)
ser.str.contains('60 Hz').sum()
# Out:
# array(['1 Year Warranty', '60 Hz Refresh Rate', '50 Hz Refresh Rate',
#        '1 Year Warranty on Product', 'A+ Grade Panel',
#        'A+ Grade Premium Dot Free Panel', 'Thin Bezel Design',
#        'Zero Dot A+ Panel', 'A+ Grade', 'A+Grade',
#        '1 Year Candes Domestic Warranty',
#        '1 Year Comprehensive Warranty and 1 Year Additional on Panel',
#        'LED', '3 x HDMI | 1 x USB', '1 year comprehensive warranty',
#        '120 Hz Refresh Rate',
#        '1 Year LG India Comprehensive Warranty and Additional 1 Year Warranty is Applicable on Panel/Module',
#        '1 Year Warranty on Product + 1 Year Additional on Panel',
#        'A+ Panel', '3 x HDMI | 2 x USB', '1 Year Manufacturer Warranty',
#        '2 x HDMI | 1 x USB', '100 Hz Refresh Rate',
#        '1 year sony Domestic Warranty', '800 Hz Refresh Rate',
#        '200 Hz Refresh Rate',
#        '1 Year LG India Comprehensive Warranty and additional 1 year Warranty is applicable on panel/module',
#        'A+', '1 Year Manufaturer Warranty', '4 x HDMI | 3 x USB', 'IPS',
#        '3 Years Warranty on Product',
#        '1 Year Warranty on Product and Additional 1 Year for Panel',
#        '3 x HDMI | 3 x USB', '1 Year From Date of Purchase',
#        '2 Year Comprehensive Domestic Warranty', 'VA', '1 YEAR',
#        '1 Year Comprehensive Warranty on Product and Additional 1 Year on Panel',
#        '1 Year on product', 'A+ Grade IPS', '2 YEAR', '2 Years',
#        '1 Year Standard Warranty and 1 Year Warranty on Panel from Samsung',
#        '1 Year Comprehensive Warranty', 'COMES WITH  1YR  WARRANTY',
#        '1 + 1 Year Warranty',
#        '1 Year Comprehensive Warranty and 1 Year Additional Warranty on Panel',
#        '1 Year Company Warranty', 'A Grade', 'A Grade Panel',
#        '1 + 2 Year',
#        '1 Year Standard Warranty Provided By The Manufacturer From Date Of Purchase',
#        'LED Panel', '2 x HDMI | 2 x USB', '1 x HDMI | 1 x USB',
#        'Zero Dots LED Panel', '1 Year Maser India Warranty',
#        '3 Years Warranty'], dtype=object)
# array(['60 Hz Refresh Rate', 'HD Ready 1366 x 768 Pixels',
#        'Ultra HD (4K) 3840 x 2160 Pixels', 'Full HD 1920 x 1080 Pixels',
#        'Ultra HD (4K) Crystal 4K FE UHD (3840 x 2160) Pixels',
#        'Full HD 1080 x 1920 Pixels', 'HD Ready 1366 x768 Pixels',
#        'Ultra HD (4K) 3840×2160 Pixels', 'Full HD 1920x1080 Pixels',
#        'Ultra HD (4K) 3860 x 2160 Pixels',
#        'Ultra HD (4K) 3840X2160 Pixels', '24W Speaker Output',
#        'Ultra HD (4K) 3840 × 2160 Pixels',
#        'Ultra HD (4K) 3840*2160 Pixels', 'Ultra HD (4K) 3840x2160 Pixels',
#        '120 Hz Refresh Rate', '100 Hz Refresh Rate',
#        '20 W Speaker Output', '200 Hz Refresh Rate',
#        '16 W Speaker Output', '58 Hz Refresh Rate', '40 W Speaker Output',
#        '50 Hz Refresh Rate', '16W Speaker Output',
#        'Full HD 1366x814 Pixels', 'Full HD 1366x785 Pixels',
#        'HD Ready 1366x768 Pixels', 'Full HD 1366x770 Pixels',
#        'Ultra HD (8K) 7680 x 4320 Pixels', 'Full HD 1366x796 Pixels',
#        '20 Speaker Output', 'Full HD 1366x768 Pixels',
#        'Full HD 1366x778 Pixels', 'Full HD 1366x812 Pixels',
#        'Ultra HD (4K) 3840 � 2160 Pixels', 'Full HD 1366x777 Pixels',
#        'Full HD 1366x779 Pixels', 'Full HD 1920*1080 Pixels',
#        'Full HD 1366x799 Pixels', 'Full HD 1366x800 Pixels',
#        'Full HD 1366x782 Pixels', 'Full HD 1366x769 Pixels',
#        'Full HD 1366x805 Pixels', 'Full HD 1366x794 Pixels',
#        'Full HD 1366x811 Pixels', 'Full HD 1366x803 Pixels',
#        'Full HD 1366x787 Pixels', 'Full HD 1366x783 Pixels',
#        '60 Hz Refresh Rate for a blur-free picture quality',
#        'Full HD 1366x775 Pixels', 'Full HD 1366x797 Pixels',
#        'Full HD 1366x780 Pixels', 'Full HD 1366x786 Pixels',
#        'Full HD 1366x772 Pixels', 'Full HD 1366x817 Pixels',
#        'Full HD 1366x792 Pixels', 'Full HD 1366x774 Pixels',
#        'Full HD 1366x781 Pixels', 'Full HD 1366x798 Pixels',
#        'Full HD 1366x771 Pixels', 'Full HD 1366x813 Pixels',
#        '300 Hz Refresh Rate', '16 Speaker Output'], dtype=object)
# array(['2 x HDMI | 2 x USB', '20 W Speaker Output', '10 W Speaker Output',
#        '20 Speaker Output', '30 W Speaker Output', '24 W Speaker Output',
#        '24W Speaker Output', '40 W Speaker Output', '60 W Speaker Output',
#        '1 x HDMI | 2 x USB', '30W Speaker Output', '48 W Speaker Output',
#        '16 W Speaker Output', '39 W Speaker Output',
#        '50 W Speaker Output', '19 W Speaker Output',
#        '44 W Speaker Output', '2 x HDMI | 1 x USB', '1 x HDMI | 1 x USB',
#        '60 Hz Refresh Rate', '24 rms Speaker Output',
#        '20 rms Speaker Output', '20 WATT Speaker Output',
#        '36 W Speaker Output', '16 rms Speaker Output',
#        '102 W Speaker Output', '20W Speaker Output', '3 x HDMI | 2 x USB',
#        '4 x HDMI | 3 x USB', '100 W Speaker Output',
#        '20W x 2 Speaker Output', '50 Hz Refresh Rate',
#        '40 Speaker Output', '40W x 2 Speaker Output',
#        '4 x HDMI | 2 x USB', '12 W Speaker Output', '0 x HDMI | 1 x USB',
#        '2 x HDMI | 3 x USB', '40W Speaker Output',
#        '24W x 48 Speaker Output', '3 x HDMI | 1 x USB',
#        '200 Hz Refresh Rate', '3 x HDMI | 3 x USB', '20 w Speaker Output',
#        '24W x 19 Speaker Output', '24W x 4 Speaker Output',
#        '120 Hz Refresh Rate', '100 Hz Refresh Rate',
#        '24W x 30 Speaker Output', '10 W x 2 Speaker Output',
#        '24W x 2 Speaker Output', '24W x 12 Speaker Output',
#        '24W x 46 Speaker Output', '12W x 2 Speaker Output',
#        '24W x 11 Speaker Output', '24W x 13 Speaker Output',
#        '10 w *2 Speaker Output', '24W x 33 Speaker Output',
#        '24W x 34 Speaker Output', '24W x 16 Speaker Output',
#        '24W x 3 Speaker Output', '24W x 39 Speaker Output',
#        '24W x 28 Speaker Output', '24W x 45 Speaker Output',
#        '24W x 37 Speaker Output', '24W x 21 Speaker Output',
#        '8W X 2 W Speaker Output', '24W x 17 Speaker Output',
#        '18W X 2 W Speaker Output', '24W x 9 Speaker Output',
#        '24W x 31 Speaker Output', '24W x 14 Speaker Output',
#        '24W x 20 Speaker Output', '24W x 6 Speaker Output',
#        '24W x 51 Speaker Output', '24W x 26 Speaker Output',
#        '24W x 8 Speaker Output', '24W x 15 Speaker Output',
#        '24W x 32 Speaker Output', '24W x 5 Speaker Output',
#        '24W x 47 Speaker Output', '24 Speaker Output',
#        '40 rms Speaker Output', '98 W Speaker Output',
#        '8 W x 2 Speaker Output'], dtype=object)
# 0      1 Year Warranty60 Hz Refresh Rate2 x HDMI | 2 ...
# 1      60 Hz Refresh RateHD Ready 1366 x 768 Pixels20...
# 2      50 Hz Refresh RateHD Ready 1366 x 768 Pixels10...
# 3      60 Hz Refresh RateHD Ready 1366 x 768 Pixels20...
# 4      60 Hz Refresh RateHD Ready 1366 x 768 Pixels20...
#                              ...
# 661           1 YEAR60 Hz Refresh Rate2 x HDMI | 1 x USB
# 662    50 Hz Refresh RateUltra HD (4K) 3840 x 2160 Pi...
# 663    3 Years Warranty60 Hz Refresh Rate2 x HDMI | 2...
# 664    2 x HDMI | 2 x USB16 Speaker Output50 Hz Refre...
# 665           1 YEAR50 Hz Refresh Rate2 x HDMI | 2 x USB
# Length: 666, dtype: object
# 510

# %% [markdown]
# ### Q02.
#
# TV의 해상도(`Picture_quality`)는 HD, 4K, 8K로 나뉜다. 최근 시장에 등장한 8K 제품군은 상대적으로 비싸 비교적 매출이 떨어지는 편이다. 하지만 8K 제품군 구매자가 4K 제품군 구매자 대비 얼마나 만족하고 있는지 확인해보고자 한다.
# 8K 제품군의 평가 평균 점수(`Stars`)의 평균값과 4K 제품군의 평가 평균 점수와의 평균값 차이의 절대값을 산출하시오.
#
# ※ 화면 해상도는 관련 변수에서 `"HD"`, `"4K"`, `"8K"`로 찾아낼 수 있다.
# ※ 화면 해상도 정보는 `"Operating_system"`, `"channel"`, `"Picture_quality"` 변수에 흩어져 있다.
# ※ 결과는 반올림하여 소수점 둘째 자리까지 출력하시오. `(정답 예시: 0.12)`

# %%
df_q2 =df.copy()
display(df_q2['Picture_quality'].value_counts())
display(df_q2['Operating_system'].apply(type).value_counts())
display(df_q2['channel'].apply(type).value_counts())
display(df_q2['Picture_quality'].apply(type).value_counts())

df_q2['quality'] = df_q2['Operating_system'] + df_q2['channel'] + df_q2['Picture_quality']
ser_cond_4K = df_q2['quality'].str.contains("4K") #string 객체에 한해서 .str이 가능!
ser_cond_8K = df_q2['quality'].str.contains("8K")
mean_4k = df_q2.loc[ser_cond_4K, :]['Stars'].mean()
mean_8k = df_q2.loc[ser_cond_8K, :]['Stars'].mean()
round(abs(mean_4k - mean_8k), 2)
# Out:
# Ultra HD (4K) 3840 x 2160 Pixels    305
# HD Ready 1366 x 768 Pixels           98
# Full HD 1920 x 1080 Pixels           77
# 60 Hz Refresh Rate                   76
# 20 W Speaker Output                  10
#                                    ...
# Full HD 1366x777 Pixels               1
# Full HD 1366x779 Pixels               1
# Full HD 1920*1080 Pixels              1
# Full HD 1366x799 Pixels               1
# 16 Speaker Output                     1
# Name: Picture_quality, Length: 63, dtype: int64
# <class 'str'>    666
# Name: Operating_system, dtype: int64
# <class 'str'>    666
# Name: channel, dtype: int64
# <class 'str'>    666
# Name: Picture_quality, dtype: int64
# 0.38

# %% [markdown]
# ### Q03.
#
# 좋은 평가를 받는 제품의 조건을 알아보고자 한다. 이를 위해 기존 변수와 더불어 여러 파생변수를 생성 후 해당 변수들을 독립변수로 하고 평가 평균 점수(`Stars`)를 종속변수로 하여 Random Forest 분석을 통해 좋은 평가를 받는 제품의 조건을 알아보고자 한다.
# 아래 절차를 수행하여 변수 중요도를 확인하고, 그 값 중 가장 큰 값을 가진 변수명을 기술하시오.
#
# | 구분 | 변수 |
# |---|---|
# | 독립변수 | 후기 작성 비율: 후기 수(`Reviews`) / 평가 수(`Ratings`) |
# | . | 공장 출고가(`MRP`) |
# | . | 할인율: 현재 판매가(`current_price`) / 공장 출고가(`MRP`) |
# | . | Netflix 제공 여부: 제공(1), 미제공(0) |
# | . | Prime Video 제공 여부: 제공(1), 미제공(0) |
# | . | 고해상도 여부: 4K 또는 8K(1), 나머지 0 |
# | 종속변수 | 평가 평균 점수(`Stars`) |
#
# ※ `channel` 변수에 해상도(`'Pixel'` 문자 참조) 또는 운영체제 정보(`'Oper'` 문자 참조)가 있는 TV는 분석에서 제외하시오.
# ※ Netflix와 Prime Video 제공여부 변수는 `channel` 변수를 참고하시오.
# ※ 독립변수를 생성하면서 결측치가 생성되는 경우 해당 행을 모두 제거하시오.
# ※ 학습 대상이 되는 행 개수는 197이다.
# ※ 고해상도 여부 변수 생성은 해상도(`Picture_quality`) 변수만 참고하여 생성하시오.
# ※ `seed`는 123으로 지정하시오. `(정답 예시: 고해상도여부 - 띄어쓰기 않고 문제에서 제시된 독립변수명을 기입)`

# %%
df_q3 = df.copy()
df_q3['R/R'] = df_q3['Reviews']/df_q3['Ratings']
df_q3['C/M'] = df_q3['current_price']/df_q3['MRP']

display(df_q3['channel'].apply(type).value_counts(), df_q3['channel'].unique())
display(df_q3.shape)

ser_cond3 = ~df_q3['channel'].str.contains('Pixel') #string은 str.contains() 가능
df_q3 = df_q3.loc[ser_cond3, :].copy()
display(df_q3.shape)

ser_cond4 = ~df_q3['channel'].str.contains('Oper') #string은 str.contains() 가능
df_q3 = df_q3.loc[ser_cond4, :].copy()
display(df_q3.shape)

ser_cond5 = df_q3['channel'].str.contains('Netflix')
df_q3['Netflix'] = ser_cond5
df_q3['Netflix'] = df_q3['Netflix'].replace({
    True : 1,
    False : 0
}).astype(int)
display(df_q3['Netflix'].value_counts())

ser_cond6 = df_q3['channel'].str.contains('Prime Video')
df_q3['PrimeVideo'] = ser_cond6
df_q3['PrimeVideo'] = df_q3['PrimeVideo'].replace({
    True : 1,
    False : 0
}).astype(int)
display(df_q3['PrimeVideo'].value_counts())

ser_cond6 = df_q3['Picture_quality'].str.contains('4K|8K') # 정규식 검색 가능
df_q3['High_Picture_Quality'] = ser_cond6
df_q3['High_Picture_Quality'] = df_q3['High_Picture_Quality'].replace({
    True : 1,
    False : 0
}).astype(int)
display(df_q3['High_Picture_Quality'].value_counts())
display(df_q3.columns)
df_q3 = df_q3.dropna()
display(df_q3.columns)

#D
cols_X = ['R/R', 'MRP', 'C/M', 'Netflix', 'PrimeVideo', 'High_Picture_Quality']
X = df_q3[cols_X].copy()
y = df_q3['Stars']
display(X.shape, y.shape)
#N

#M
model = RandomForestRegressor(random_state = 123)
model.fit(X,y)
model.feature_importances_

dict_ser = dict(zip(cols_X, model.feature_importances_))
display(dict_ser)
ser_dict = pd.Series(dict_ser)
display(ser_dict.max(), ser_dict.idxmax())
#E
# Out:
# <class 'str'>    666
# Name: channel, dtype: int64
# array(['HD Ready 1366 x 768 Pixels', 'Netflix|Disney+Hotstar|Youtube',
#        'Netflix|Prime Video|Disney+Hotstar|Youtube',
#        'HD Ready 1366 X 768 Pixels', 'Netflix|Prime Video|Youtube',
#        'Youtube', 'Prime Video|Disney+Hotstar|Youtube',
#        'Prime Video|Youtube', 'Netflix|Youtube',
#        'HD Ready 1366 x 786 Pixels', 'Disney+Hotstar|Youtube',
#        'HD Ready 1366*768 Pixels', 'Ultra HD (4K) 3840 x 2160 Pixels',
#        'Netflix|Prime Video|Apple TV|Disney+Hotstar|Youtube',
#        'HD Ready 720p Pixels', 'Ultra HD (4K) ?3840 x 2160 Pixels',
#        'Operating System: Linux', 'Full HD 1920 x 1080 Pixels',
#        'Operating System: Android', 'Ultra HD (4K) 3840*2160 Pixels',
#        'Operating System: WebOS', 'Operating System: Tizen',
#        'Ultra HD (4K) 3840 x 2160 - Ultra HD Pixels',
#        'Ultra HD (4K) 4K QLED (3840 x 2160) Pixels', 'Prime Video',
#        'Ultra HD (4K) 3840 * 2160 Pixels', 'HD Ready 1366X768P Pixels',
#        'Full HD 1980 x 1080 Pixels', 'Operating System: Android Based',
#        'Full HD 1366 x 768 Pixels', 'HD Ready 1920 x 1080 - FHD Pixels',
#        'HD Ready 1920 x 1080 Pixels', 'HD Ready ?1366*768 Pixels',
#        'HD Ready 1366X768 Pixels', 'Ultra HD (4K) 1920 x 1080 Pixels',
#        'Operating System: HomeOS',
#        'Ultra HD (4K) 3840 x 2160 pixels Pixels'], dtype=object)
# (666, 13)
# (567, 13)
# (548, 13)
# 1    518
# 0     30
# Name: Netflix, dtype: int64
# 1    339
# 0    209
# Name: PrimeVideo, dtype: int64
# 1    329
# 0    219
# Name: High_Picture_Quality, dtype: int64
# Index(['Product_Name', 'Stars', 'Ratings', 'Reviews', 'current_price', 'MRP',
#        'channel', 'Operating_system', 'Picture_quality', 'Speaker',
#        'Frequency', 'R/R', 'C/M', 'Netflix', 'PrimeVideo',
#        'High_Picture_Quality'],
#       dtype='object')
# Index(['Product_Name', 'Stars', 'Ratings', 'Reviews', 'current_price', 'MRP',
#        'channel', 'Operating_system', 'Picture_quality', 'Speaker',
#        'Frequency', 'R/R', 'C/M', 'Netflix', 'PrimeVideo',
#        'High_Picture_Quality'],
#       dtype='object')
# (197, 6)
# (197,)
# {'R/R': 0.3122061680649266,
#  'MRP': 0.17383962649966622,
#  'C/M': 0.4446911950647382,
#  'Netflix': 0.027140866837663043,
#  'PrimeVideo': 0.02400441733105043,
#  'High_Picture_Quality': 0.01811772620195551}
# 0.4446911950647382
# 'C/M'
